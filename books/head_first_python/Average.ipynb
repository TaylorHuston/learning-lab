# %%
FN = "Darius-13-100m-Fly.txt"
FOLDER = "swimdata/"
with open(FOLDER + FN) as file:
  lines = file.readlines()

# %%
type(lines)
# Out:
# list

# %%
lines[0]
# Out:
# '1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n'

# %%
times = lines[0].strip().split(',')

# %%
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
first = times[0]
minutes, rest = first.split(':')
seconds, hundredths = rest.split('.')

converted_time = int(minutes) * 6000 + int(seconds) * 100 + int(hundredths)

print(converted_time)
# Out:
# 8795

# %%
converts = []
for t in times:
    minutes, rest = t.split(':')
    seconds, hundredths = rest.split('.')
    converted_time = int(minutes) * 6000 + int(seconds) * 100 + int(hundredths)
    print(t,"->",converted_time)
    converts.append(converted_time)
# Out:
# 1:27.95 -> 8795
# 1:21.07 -> 8107
# 1:30.96 -> 9096
# 1:23.22 -> 8322
# 1:27.95 -> 8795
# 1:28.30 -> 8830

# %%
import statistics
avg = statistics.mean(converts)

# %%
minutes_seconds, hundredths = str(round(avg / 100, 2)).split('.')
minutes = int(int(minutes_seconds) // 60)
seconds = int(minutes_seconds) - minutes * 60
average = str(minutes) + ':' + str(seconds).zfill(2) + '.' + hundredths

average
# Out:
# '1:26.58'
