# %%
import swimclub

# %%
data = swimclub.read_swim_data("Darius-13-100m-Fly.txt")

# %%
times = data[4]
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimmer, age, distance, stroke, times2, average = data

times2
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
import os

swim_files = os.listdir(swimclub.FOLDER)
len(swim_files)
# Out:
# 60

# %%
for n, swim_file in enumerate(swim_files, 1):
    print(n,"Reading data from file:", swim_file)
    swimclub.read_swim_data(swim_file)
# Out:
# 1 Reading data from file: Abi-10-50m-Breast.txt
# 2 Reading data from file: Blake-15-100m-Free.txt
# 3 Reading data from file: Carl-15-100m-Back.txt
# 4 Reading data from file: Mike-15-100m-Back.txt
# 5 Reading data from file: Calvin-9-50m-Free.txt
# 6 Reading data from file: Bill-18-200m-Back.txt
# 7 Reading data from file: Darius-13-100m-Back.txt
# 8 Reading data from file: Chris-17-100m-Back.txt
# 9 Reading data from file: Ruth-13-100m-Free.txt
# 10 Reading data from file: Tasmin-15-100m-Back.txt
# 11 Reading data from file: Lizzie-14-100m-Back.txt
# 12 Reading data from file: Katie-9-50m-Breast.txt
# 13 Reading data from file: Alison-14-100m-Breast.txt
# 14 Reading data from file: Hannah-13-100m-Free.txt
# 15 Reading data from file: Tasmin-15-100m-Breast.txt
# 16 Reading data from file: Calvin-9-50m-Fly.txt
# 17 Reading data from file: Tasmin-15-100m-Free.txt
# 18 Reading data from file: Abi-10-50m-Free.txt
# 19 Reading data from file: Darius-13-100m-Fly.txt
# ...
